# %% [markdown]
# <a href="https://colab.research.google.com/github/SutapaNayak/Exploratory-data-analysis/blob/main/Breastcancer_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-b4b3c02e-ee1a-4167-a26e-5797d6fcb04d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b4b3c02e-ee1a-4167-a26e-5797d6fcb04d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving haberman.csv to haberman.csv

# %%
data=pd.read_csv("haberman.csv")

# %%
data.head()
# Out:
#    age  year  nodes  status
# 0   30    64      1       1
# 1   30    62      3       1
# 2   30    65      0       1
# 3   31    59      2       1
# 4   31    65      4       1

# %%
data.shape
# Out:
# (305, 4)

# %%
data.columns
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
data["status"].value_counts()
# Out:
# 1    225
# 2     80
# Name: status, dtype: int64

# %%
data.isnull().sum()
# Out:
# age       0
# year      0
# nodes     0
# status    0
# dtype: int64

# %%
sns.heatmap(data.isnull(),yticklabels=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     305 non-null    int64
#  1   year    305 non-null    int64
#  2   nodes   305 non-null    int64
#  3   status  305 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
sns.countplot(x='status',data=data)

# %%
data.describe()
# Out:
#               age        year       nodes      status
# count  305.000000  305.000000  305.000000  305.000000
# mean    52.357377   62.868852    4.032787    1.262295
# std     10.678010    3.242783    7.200528    0.440605
# min     30.000000   58.000000    0.000000    1.000000
# 25%     44.000000   60.000000    0.000000    1.000000
# 50%     52.000000   63.000000    1.000000    1.000000
# 75%     60.000000   66.000000    4.000000    2.000000
# max     78.000000   69.000000   52.000000    2.000000

# %% [markdown]
# Bivariate analysis

# %%
sns.set_style('whitegrid')
sns.FacetGrid(data,hue='status').map(plt.scatter,'age','year').add_legend()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(data,hue='status').map(plt.scatter,'age','nodes').add_legend()

# %% [markdown]
# Pair plot

# %%
sns.set_style('whitegrid')
sns.pairplot(data,hue='status',vars=['age','year','nodes'],palette='gist_rainbow')

# %% [markdown]
# Univariate

# %%
live=data.loc[data['status']==1]
dead=data.loc[data['status']==2]

# %%
plt.plot(live['age'],np.zeros_like(live['age']),'o')#blue dots
plt.plot(dead['age'],np.zeros_like(dead['age']),'o')#orange dots

# %%
sns.FacetGrid(data,hue='status').map(sns.distplot,'year')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(data, hue='status').map(sns.distplot, 'age')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data['age'],color='darkred')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data['age'],color='darkred')

# %%
sns.distplot(data['year'],color='darkred')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data['nodes'],color='darkred')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(x='status',y='age',data=data)
plt.show()

# %%
sns.boxplot(x='status',y='nodes',data=data)
plt.show()
